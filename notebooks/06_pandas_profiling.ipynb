# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.3.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (3.10.9)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.12.4)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.3.5)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [27 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\Admin\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "C:\Users\Admin\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Admin\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\Admin\AppData\Local\Temp\pip-build-env-tosrc5e9\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Admin\AppData\Local\Temp\pip-build-env-tosrc5e9\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "C:\Users\Admin\AppData\Local\Temp\pip-build-env-tosrc5e9\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Admin\AppData\Local\Temp\pip-build-env-tosrc5e9\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 4, in <module>
#         File "C:\Users\Admin\AppData\Local\Temp\pip-install-qa6kydmo\htmlmin_268f8ac4488f4ca7bea8529a7c04d4cd\htmlmin\__init__.py", line 28, in <module>
#           from .main import minify, Minifier
#         File "C:\Users\Admin\AppData\Local\Temp\pip-install-qa6kydmo\htmlmin_268f8ac4488f4ca7bea8529a7c04d4cd\htmlmin\main.py", line 28, in <module>
#           import cgi
#       ModuleNotFoundError: No module named 'cgi'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'htmlmin' when getting requirements to build wheel

# %%
import pandas as pd
from pandas_profiling import ProfileReport

from pathlib import Path
# Load the dataset
Project_Root = Path.cwd().parent

Data_Path = Project_Root / "Data"/"processed"/"Gurgaon_merged_v2.csv"
df = pd.read_csv(Data_Path)


# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 26/26 [00:00<00:00, 45.02it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Generate the report
from pathlib import Path

Project_root = Path.cwd().parent
out_dir = Project_root / "Outputs"
out_dir.mkdir(exist_ok=True)

profile.to_file(out_dir / "pandas_profiling_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
