# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

DATA_PATH_flats= PROJECT_ROOT / "Data" / "processed" / "flats_basic_cleaned.csv"
DATA_PATH_houses = PROJECT_ROOT / "Data" / "processed" / "houses_basic_cleaned.csv"

df_flats = pd.read_csv(DATA_PATH_flats)
df_houses = pd.read_csv(DATA_PATH_houses)

# %%
df = pd.concat([df_flats, df_houses], ignore_index=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (3961, 21)

# %%
df.shape
# Out:
# (3961, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3391 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         2992 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
# ...

# %%
df['floorNum'] = df['floorNum'].fillna(df['noOfFloor'])
df.drop(columns=['noOfFloor'], inplace=True)

# %%
df.head(50)
# Out:
#                                   property_name property_type  \
# 0                  2 BHK Flat in Krishna Colony          flat
# 1                     2 BHK Flat in Ashok Vihar          flat
# 2                           2 BHK Flat in Sohna          flat
# 3               2 BHK Flat in Sector 61 Gurgaon          flat
# 4               2 BHK Flat in Sector 92 Gurgaon          flat
# 5               2 BHK Flat in Sector 36 Gurgaon          flat
# 6       3 BHK Flat in Dwarka Expressway Gurgaon          flat
# 7              3 BHK Flat in Sector 104 Gurgaon          flat
# 8              2 BHK Flat in Sector 88B Gurgaon          flat
# 9               3 BHK Flat in Sector 78 Gurgaon          flat
# 10              2 BHK Flat in Sector 81 Gurgaon          flat
# 11                          2 BHK Flat in Sohna          flat
# 12              3 BHK Flat in Sector 79 Gurgaon          flat
# 13              2 BHK Flat in Sector 33 Gurgaon          flat
# ...

# %%
df.insert(loc = 3, column = 'sector', value = df['property_name'].str.split("in").str.get(1).str.replace("Gurgaon", "").str.strip())

# %%
df.sector = df.sector.str.lower()

# %%
df.sector.unique()
# Out:
# array(['krishna colony', 'ashok vihar', 'sohna', 'sector 61', 'sector 92',
#        'sector 36', 'dwarka expressway', 'sector 104', 'sector 88b',
#        'sector 78', 'sector 81', 'sector 79', 'sector 33', 'sector 90',
#        'sector 108', 'sector 62', 'sector 102', 'sector 93',
#        'sector-33 sohna', 'sector 89', 'sector 113', 'sector 65',
#        'sector 48', 'sector 37c', 'sector 3', 'new palam vihar',
#        'sector 43', 'sector 88a', 'sector 68', 'sector 109', 'sector 106',
#        'sector 82', 'ashok vihar phase 3 extension', 'sector 85',
#        'sector 82a', 'dlf phase 4', 'sector 10a', 'sector 1a imt manesar',
#        'block a surya vihar', 'sector 84', 'sector 71', 'sector-7 hous',
#        'sector 77', 'sector 37d', 'sector 67a', 'sector 57', 'sector 95',
#        'sector 99a', 'sector 103', 'sector 49', 'sector 30', 'sector 86',
#        'sector 66', 'sector 15 part 1', 'laxman vihar', 'sector 22',
# ...

# %%
sector_map = {
    'krishna colony': 'sector 7',
    'ashok vihar': 'sector 5',
    'sohna': 'sector 48',
    'dwarka expressway': 'sector 102',
    'new palam vihar': 'sector 1',
    'ashok vihar phase 3 extension': 'sector 5',
    'dlf phase 4': 'sector 28',
    'block a surya vihar': 'sector 21',
    'sector-7 hous': 'sector 7',
    'sushant lok phase 1': 'sector 43',
    'sohna road': 'sector 48',
    'ashok vihar phase 2': 'sector 5',
    'rajiv colony': 'sector 12A',
    'garauli kalan': 'sector 9',
    'bhawani enclave': 'sector 9B',
    'iffco chowk': 'sector 18',
    'palam vihar': 'sector 1',
    'near sector 1 market': 'sector 1',
    'gwal pahari': 'sector 61',
    'malibu town': 'sector 47',
    'golf course road': 'sector 53',
    'kanahi': 'sector 45',
    'dlf phase 5': 'sector 43',
    'nirvana country': 'sector 50',
    'dlf phase 2': 'sector 25',
    'heritage city': 'sector 62',
    'ambience island': 'sector 24',
    'suncity': 'sector 54',
    'sai kunj': 'sector 47',
    'manesar': 'sector 1A IMT Manesar',
    'imt manesar': 'sector 1A IMT Manesar',
    'mg road': 'sector 28',
    'sultanpur': 'sector 56',
    'civil l': 'sector 15',
    'new colony, sector 7': 'sector 7',
    'lajpat nagar': 'sector 14',
    'new': 'sector unknown',
    'surya vihar': 'sector 21',
    'near pataudi chowk': 'sector 10',
    'cyber city': 'sector 24',
    'new colony': 'sector 7',
    'subhash nagar': 'sector 12',
    'ats marigold': 'sector 89',
    'adarsh nagar': 'sector 7',
    'sushant lok phase 3': 'sector 57',
    'carterpuri village': 'sector 23A',
    'valley view estate': 'sector 57',
    'shanti nagar': 'sector 11',
    'sushant lok': 'sector 43',
    'mehrauli road': 'sector 14',
    'faridabad road': 'sector 58',
    'sector 5 chowk': 'sector 5',
    'old delhi road, opp sector-14': 'sector 14',
    'dayananad colony': 'sector 6',
    'samaspur': 'sector 59',
    'nirvana country pocket h': 'sector 50',
    'patel nagar': 'sector 14',
    'surat nagar 1': 'sector 104',
    'sispal vihar': 'sector 49',
    'golf course ext road': 'sector 58',
    'shankar vihar': 'sector 28',
    'bhondsi': 'sector 76',
    'palam vihar extension': 'sector 1',
    'saroop garden rajendra park': 'sector 15',
    'bptp': 'sector 66',
    'south city 1': 'sector 40',
    'dharam colony': 'sector 23A',
    'rajendra park': 'sector 8',
    'dlf phase 1': 'sector 26',
    'new palam vihar phase 1': 'sector 2',
    'uppals southend': 'sector 49',
    'nars': 'sector unknown',
    'greenwood city': 'sector 45',
    'shivaji nagar': 'sector 11',
    'hira nagar': 'sector 7',
    'gopal nagar, garhi ghasita, sonipat': 'not gurgaon',
    'jat colony,fazilpur/taj nagar road': 'sector 49',
    'kheri': 'sector 5',
    'madanpuri': 'sector 7',
    'mohan nagar': 'sector 6',
    'daulatabad': 'sector 4',
    'vishnu garden': 'sector 5',
    'new basti': 'sector 7',
    'maruti kunj': 'sector 107',
    'laxmi garden': 'sector 7',
    'saraswati vihar': 'sector 28',
    'bhora kalan': 'not gurgaon',
    'near nand hospital': 'sector unknown',
    'shivpuri': 'sector 11',
    'jyoti park': 'sector 12',
    'surat nagar phase 2': 'sector 104',
    'rajiv nagar': 'sector 12A',
    'arjun nagar': 'sector 4',
    'ashok vihar phase i': 'sector 5',
    'block h ashok vihar phase iii extension': 'sector 5',
    'devilal colony': 'sector 12A',
    'prem nagar': 'sector 11',
    'bhim nagar': 'sector 14',
    'surat nagar': 'sector 104',
    'gandhi nagar': 'sector 5',
    'khandsa': 'sector 10',
    'ravi nagar': 'sector 5',
    'west rajiv nagar': 'sector 12A',
    'near khandsa road': 'sector 10',
    'sheetla colony': 'sector 5',
    'farukhnagar': 'not gurgaon',
    'mianwali colony': 'sector 12A',
    'lucknow': 'not gurgaon',
    'pataudi road': 'sector 10',
    'shakti nagar': 'sector 6',
    'baldev nagar': 'sector 7',
    'acharya puri': 'sector 7',
    'garhi harsaru': 'sector 36',
    'pratap nagar': 'sector 5',
    'manohar nagar': 'sector 8',
    'vir nagar': 'sector 8',
    'hno 13 sagar enclave sura': 'sector 9',
    'ram nagar': 'sector 8',
    'om nagar': 'sector 10',
    'jacobpura': 'sector 12',
    'tekchand nagar': 'sector 9',
    'ashok vihar phase 3': 'sector 5',
    "ansal's palam vihar": 'sector 1',
    'jacobpura near sadar bazar': 'sector 12',
    'shivji park colony': 'sector 7',
    'udyog vihar phase 1': 'sector 18',
    'mahalaxmi garden, rajendra place': 'sector 7',
    'rattan garden': 'sector 7',
    'sadar bazar': 'sector 12',
    'naharpur rupa': 'sector 12',
    'laxman vihar, railway road,': 'sector 4',
    'sector-5 sheetla colony': 'sector 5',
    'damdma': 'not gurgaon',
    ', delhi ncr': 'not gurgaon',
    'new jyoti park': 'sector 12',
    'sohna  road': 'sector 48',
    'mahavir pura': 'sector 7',
    'park view': 'sector 45',
    'ravi nager basai road': 'sector 9',
    'begampur khatola': 'sector 35',
    'dhankot': 'sector 102',
    'rajiv chowk': 'sector 29',
    'devi lal colony gali no 12 gurgaon nr omkar public school': 'sector 12A',
    'alipur': 'not gurgaon',
    'saraswati enclave': 'sector 28',
    'sec 3 bhim vihar part 1 bhimgher kheri': 'sector 3',
    'near euro': 'sector unknown',
    'bhimgarh kheri phase 3': 'sector 3',
    'huda saraswati vihar': 'sector 28',
    'laxmna vihar, phase 2': 'sector 4',
    'sushant lok phase 2': 'sector 55',
    'ansal plaza': 'sector 56',
    'a block sushant lok phase 1': 'sector 43',
    'mayfield garden': 'sector 47',
    'south city': 'sector 40',
    'rosewood': 'sector 49',
    'v block dlf phase 3': 'sector 24',
    'bissar': 'not gurgaon'
}

# %%
# Replace known non-sector locality names with their sector without turning unmatched values into NaN.
df["sector"] = df["sector"].replace(sector_map)

# %%
df.sector.value_counts()
# Out:
# sector
# sector 48                233
# sector 102               122
# sector 85                110
# sector 92                104
# sector 69                 94
#                         ...
# sector 4 urban estate      1
# sector-35 sohna            1
# sector-5 sohna             1
# sector 37a                 1
# sector 42                  1
# Name: count, Length: 156, dtype: int64

# %%
df.sector.isnull().sum()
# Out:
# np.int64(0)

# %%
df.head(5)
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#       sector  price  price_per_sqft    area  \
# 0   sector 7   0.45          5000.0   900.0
# 1   sector 5   0.50          7692.0   650.0
# 2  sector 48   0.40          6722.0   595.0
# 3  sector 61   1.47         12250.0  1200.0
# 4  sector 92   0.70          5204.0  1345.0
#
#                              areaWithType  bedRoom  bathroom  ...  \
# 0          Carpet area: 900 (83.61 sq.m.)        2         2  ...
# 1          Carpet area: 650 (60.39 sq.m.)        2         2  ...
# ...

# %%
df.shape
# Out:
# (3961, 21)

# %%
df.drop(columns = ["property_name","address"], inplace = True, axis = 1)

# %%
df.shape
# Out:
# (3961, 19)

# %%
df['society'].fillna('independent', inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19720\3479342557.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['society'].fillna('independent', inplace=True)

# %%
df.to_csv(PROJECT_ROOT / "Data" / "processed" / "Gurgaon_merged.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_type    3961 non-null   object
#  1   society          3961 non-null   object
#  2   sector           3961 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  floorNum         3937 non-null   float64
#  12  facing           2784 non-null   object
#  13  agePossession    3960 non-null   object
#  14  nearbyLocations  3754 non-null   object
#  15  description      3961 non-null   object
# ...

# %%
df.society.isnull().sum()
# Out:
# np.int64(0)
