# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
from pathlib import Path
Project_dir = Path.cwd().parent
Data_Path = Project_dir / 'data' / 'processed' / 'Gurgaon_merged_v2.csv'
df = pd.read_csv(Data_Path)
df.head()
# Out:
#   property_type                 society     sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency   sector 7   0.45          5000.0
# 1          flat            apna enclave   sector 5   0.50          7692.0
# 2          flat  tulsiani easy in homes  sector 48   0.40          6722.0
# 3          flat     smart world orchard  sector 61   1.47         12250.0
# 4          flat        parkwood westend  sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    ...  carpet_area Plot_area built_up_area study room servant room  \
# 0  ...        900.0       NaN           NaN          0            0
# 1  ...        650.0       NaN           NaN          0            0
# 2  ...        595.0       NaN           NaN          0            0
# 3  ...       1200.0       NaN           NaN          1            0
# 4  ...          NaN       NaN           NaN          1            0
#
#    pooja room  store room  others  furnishing_type  luxury_score
# 0           0           0       0                2            28
# 1           0           0       0                0            37
# 2           0           0       0                2            36
# 3           0           0       0                2            76
# 4           0           0       0                2             0
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (3961, 26)

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Property_type vs Price

# %%
sns.barplot(x = df.property_type, y = df.price, palette = 'Set2', estimator = np.median)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\1460493648.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.property_type, y = df.price, palette = 'Set2', estimator = np.median)
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x = df.property_type, y = df.price, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\680117184.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.price, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.barplot(x = df.property_type, y = df.area, estimator = np.median, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\2774382584.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.property_type, y = df.area, estimator = np.median, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='area'>

# %%
sns.boxplot(x = df.property_type, y = df.area, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\2735386168.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.area, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='area'>

# %%
# Removing outliers from the dataset
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x = df.property_type, y = df.built_up_area, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\3325946712.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.built_up_area, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.barplot(x = df.property_type, y = df.price_per_sqft, palette = 'Set2', estimator = np.median)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\1498782596.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.property_type, y = df.price_per_sqft, palette = 'Set2', estimator = np.median)
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x = df.property_type, y = df.price_per_sqft, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\4246027450.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.price_per_sqft, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# Check correlation between property_type and bedroom.
sns.heatmap(pd.crosstab(df.property_type, df.bedRoom), annot = True, fmt = 'd', cmap = 'YlGnBu')
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.barplot(x = df.property_type, y = df.floorNum, palette = 'Set2', estimator = np.median)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\1465141673.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.property_type, y = df.floorNum, palette = 'Set2', estimator = np.median)
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x = df.property_type, y = df.floorNum, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\303440079.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.floorNum, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
pt = pd.pivot_table(df, index='property_type', columns='agePossession',
                    values='price', aggfunc='mean')
print(pt.shape)
print(pt)
# Out:
# (2, 6)
# agePossession  Moderately Old  New Property  Old Property  Relatively New  \
# property_type
# flat                 2.083222      1.521361      1.894818        1.675494
# house                5.320041      5.890526      4.351308        6.159773
#
# agePossession  Undefined  Under Construction
# property_type
# flat            1.746490            1.471094
# house           2.441702            3.395000

# %%
sns.heatmap(pd.pivot_table(df, index='property_type', columns='agePossession', values = 'price', aggfunc='mean'), annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(pd.pivot_table(df, index='property_type', columns='bedRoom', values = 'price', aggfunc='mean'), annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
df.head(2)
# Out:
#   property_type                 society    sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency  sector 7   0.45          5000.0
# 1          flat            apna enclave  sector 5   0.50          7692.0
#
#     area                    areaWithType  bedRoom  bathroom balcony  ...  \
# 0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2       1  ...
# 1  650.0  Carpet area: 650 (60.39 sq.m.)        2         2       1  ...
#
#    carpet_area Plot_area built_up_area study room servant room  pooja room  \
# 0        900.0       NaN           NaN          0            0           0
# 1        650.0       NaN           NaN          0            0           0
#
#    store room  others  furnishing_type  luxury_score
# 0           0       0                2            28
# 1           0       0                0            37
#
# [2 rows x 26 columns]

# %%
sns.heatmap(pd.crosstab(df.property_type, df.furnishing_type), annot = True, fmt = 'd', cmap = 'YlGnBu')
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df, index='property_type', columns='furnishing_type', values = 'price', aggfunc='mean'), annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x = df.property_type, y = df.luxury_score, palette = 'Set2', estimator = np.median)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\26317456.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.property_type, y = df.luxury_score, palette = 'Set2', estimator = np.median)
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x = df.property_type, y = df.luxury_score, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\1627140669.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df.property_type, y = df.luxury_score, palette = 'Set2')
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
# Sectoral analysis
import re
# Group by sector and calculate the mean price.
avg_price_by_sector = df.groupby('sector')['price'].mean().reset_index()

# function to extract sector number from the sector name
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    return int(match.group()) if match else None

avg_price_by_sector['sector_number'] = avg_price_by_sector['sector'].apply(extract_sector_number)

# sort the DataFrame by sector number
avg_price_by_sector_sorted_by_sector_number = avg_price_by_sector.sort_values(by='sector_number')

# %%
plt.figure(figsize=(5,25))
sns.heatmap(avg_price_by_sector_sorted_by_sector_number.set_index('sector')[['price']], annot=True)
plt.title('Average Price by Sector')
plt.xlabel('Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['luxury_score'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Luxury Score')
plt.ylabel('Sector')
plt.show()

# %%
plt.figure(figsize=(12,8))
plot_df = df[df['area'] < 10000]
sns.scatterplot(data=plot_df, x='area', y='price', hue='bedRoom')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
plot_df = df[df['area'] < 10000]
sns.scatterplot(data=plot_df, x='area', y='price', hue='agePossession')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
plot_df = df[df['area'] < 10000]
sns.scatterplot(data=plot_df, x='area', y='price', hue=df['furnishing_type'].astype('category'))
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x = df.bedRoom, y = df.price, estimator = np.median, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\531231685.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.bedRoom, y = df.price, estimator = np.median, palette = 'Set2')
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x = df.agePossession, y = df.price, estimator = np.median, palette = 'Set2')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\23143037.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.agePossession, y = df.price, estimator = np.median, palette = 'Set2')

# %%
sns.barplot(x = df.agePossession, y = df.area, estimator = np.median, palette = 'Set2')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\2742862501.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.agePossession, y = df.area, estimator = np.median, palette = 'Set2')

# %%
df.agePossession.value_counts()
# Out:
# agePossession
# Relatively New        1705
# New Property           646
# Moderately Old         610
# Undefined              501
# Old Property           353
# Under Construction     141
# Name: count, dtype: int64

# %%
sns.barplot(x = df.furnishing_type, y = df.price, estimator = np.median, palette = 'Set2')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32592\104483622.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df.furnishing_type, y = df.price, estimator = np.median, palette = 'Set2')
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(data =df, x=df.luxury_score, y=df.price)
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %%
df.head(2)
# Out:
#   property_type                 society    sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency  sector 7   0.45          5000.0
# 1          flat            apna enclave  sector 5   0.50          7692.0
#
#     area                    areaWithType  bedRoom  bathroom balcony  ...  \
# 0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2       1  ...
# 1  650.0  Carpet area: 650 (60.39 sq.m.)        2         2       1  ...
#
#    carpet_area Plot_area built_up_area study room servant room  pooja room  \
# 0        900.0       NaN           NaN          0            0           0
# 1        650.0       NaN           NaN          0            0           0
#
#    store room  others  furnishing_type  luxury_score
# 0           0       0                2            28
# 1           0       0                0            37
#
# [2 rows x 26 columns]

# %%
# Correlation analysis

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.771864
# bathroom               0.555284
# built_up_area          0.492301
# bedRoom                0.484753
# servant room           0.404394
# price_per_sqft         0.388441
# pooja room             0.339400
# store room             0.303727
# study room             0.255871
# luxury_score           0.109988
# Plot_area              0.075507
# area                   0.000067
# others                -0.007779
# carpet_area           -0.009079
# floorNum              -0.083990
# furnishing_type       -0.244962
# Name: price, dtype: float64
